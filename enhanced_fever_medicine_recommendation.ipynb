# %%
import numpy as np
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\sonia\Downloads\archive (3)\enhanced_fever_medicine_recommendation.csv")

# %%
data.head()
# Out:
#    Temperature Fever_Severity  Age  Gender   BMI Headache Body_Ache Fatigue  \
# 0         36.1         Normal   89  Female  24.0       No       Yes      No
# 1         37.5     Mild Fever   94    Male  26.6       No        No      No
# 2         36.4         Normal   92    Male  27.8       No        No      No
# 3         39.8     High Fever   66    Male  18.7       No       Yes      No
# 4         39.3     High Fever   28    Male  21.0       No       Yes      No
#
#   Chronic_Conditions Allergies Smoking_History Alcohol_Consumption  Humidity  \
# 0                 No       Yes              No                 Yes      81.4
# 1                Yes        No             Yes                 Yes      44.4
# 2                 No        No              No                 Yes      73.7
# 3                 No        No              No                  No      44.1
# 4                Yes       Yes             Yes                 Yes      65.9
#
#    AQI Physical_Activity       Diet_Type  Heart_Rate Blood_Pressure  \
# 0  430          Moderate           Vegan          72         Normal
# 1   10            Active      Vegetarian          62           High
# 2  400         Sedentary           Vegan          85           High
# 3  438            Active  Non-Vegetarian          96           High
# 4  451            Active      Vegetarian          85            Low
#
#   Previous_Medication Recommended_Medication
# 0                 NaN              Ibuprofen
# 1           Ibuprofen            Paracetamol
# 2                 NaN              Ibuprofen
# 3           Ibuprofen              Ibuprofen
# 4         Paracetamol              Ibuprofen

# %%
data.tail()
# Out:
#      Temperature Fever_Severity  Age  Gender   BMI Headache Body_Ache Fatigue  \
# 995         39.9     High Fever   59    Male  22.1      Yes       Yes     Yes
# 996         36.9         Normal   74  Female  18.1      Yes       Yes     Yes
# 997         36.1         Normal    8  Female  29.6      Yes       Yes      No
# 998         38.8     High Fever   87  Female  25.2       No        No      No
# 999         38.2     High Fever   65  Female  26.0       No       Yes      No
#
#     Chronic_Conditions Allergies Smoking_History Alcohol_Consumption  \
# 995                 No       Yes             Yes                 Yes
# 996                Yes       Yes              No                  No
# 997                 No       Yes             Yes                 Yes
# 998                 No        No              No                 Yes
# 999                 No       Yes             Yes                 Yes
#
#      Humidity  AQI Physical_Activity       Diet_Type  Heart_Rate  \
# 995      49.8   87         Sedentary      Vegetarian          67
# 996      72.5  200         Sedentary      Vegetarian          83
# 997      50.7  178          Moderate      Vegetarian          97
# 998      44.3  225         Sedentary  Non-Vegetarian          97
# 999      73.4   63            Active  Non-Vegetarian         100
#
#     Blood_Pressure Previous_Medication Recommended_Medication
# 995         Normal           Ibuprofen              Ibuprofen
# 996           High                 NaN              Ibuprofen
# 997           High                 NaN              Ibuprofen
# 998           High                 NaN              Ibuprofen
# 999         Normal                 NaN              Ibuprofen

# %%
data.shape
# Out:
# (1000, 20)

# %% [markdown]
# # Step-2 Data Understanding

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature             1000 non-null   float64
#  1   Fever_Severity          1000 non-null   object
#  2   Age                     1000 non-null   int64
#  3   Gender                  1000 non-null   object
#  4   BMI                     1000 non-null   float64
#  5   Headache                1000 non-null   object
#  6   Body_Ache               1000 non-null   object
#  7   Fatigue                 1000 non-null   object
#  8   Chronic_Conditions      1000 non-null   object
#  9   Allergies               1000 non-null   object
#  10  Smoking_History         1000 non-null   object
#  11  Alcohol_Consumption     1000 non-null   object
#  12  Humidity                1000 non-null   float64
#  13  AQI                     1000 non-null   int64
#  14  Physical_Activity       1000 non-null   object
#  15  Diet_Type               1000 non-null   object
#  16  Heart_Rate              1000 non-null   int64
#  17  Blood_Pressure          1000 non-null   object
#  18  Previous_Medication     763 non-null    object
#  19  Recommended_Medication  1000 non-null   object
# dtypes: float64(3), int64(3), object(14)
# memory usage: 156.4+ KB

# %%
data.columns
# Out:
# Index(['Temperature', 'Fever_Severity', 'Age', 'Gender', 'BMI', 'Headache',
#        'Body_Ache', 'Fatigue', 'Chronic_Conditions', 'Allergies',
#        'Smoking_History', 'Alcohol_Consumption', 'Humidity', 'AQI',
#        'Physical_Activity', 'Diet_Type', 'Heart_Rate', 'Blood_Pressure',
#        'Previous_Medication', 'Recommended_Medication'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Temperature          Age         BMI     Humidity          AQI  \
# count   1000.00000  1000.000000  1000.00000  1000.000000  1000.000000
# mean      38.09890    51.152000    26.44320    60.594400   248.493000
# std        1.13887    28.873354     4.90115    17.058475   143.705244
# min       36.00000     1.000000    18.00000    30.000000     0.000000
# 25%       37.20000    26.000000    22.40000    46.600000   127.750000
# 50%       38.20000    51.000000    26.50000    60.950000   247.500000
# 75%       39.10000    76.000000    30.52500    74.725000   375.250000
# max       40.00000   100.000000    35.00000    90.000000   499.000000
#
#        Heart_Rate
# count  1000.00000
# mean     80.14400
# std      11.79196
# min      60.00000
# 25%      70.00000
# 50%      80.00000
# 75%      90.00000
# max     100.00000

# %%
data.shape
# Out:
# (1000, 20)

# %% [markdown]
# # Checking for missing values

# %%
data.isnull().sum()
# Out:
# Temperature                 0
# Fever_Severity              0
# Age                         0
# Gender                      0
# BMI                         0
# Headache                    0
# Body_Ache                   0
# Fatigue                     0
# Chronic_Conditions          0
# Allergies                   0
# Smoking_History             0
# Alcohol_Consumption         0
# Humidity                    0
# AQI                         0
# Physical_Activity           0
# Diet_Type                   0
# Heart_Rate                  0
# Blood_Pressure              0
# Previous_Medication       237
# Recommended_Medication      0
# dtype: int64

# %%
data.describe(include='all').T
# Out:
#                          count unique             top freq     mean  \
# Temperature             1000.0    NaN             NaN  NaN  38.0989
# Fever_Severity            1000      3      High Fever  532      NaN
# Age                     1000.0    NaN             NaN  NaN   51.152
# Gender                    1000      2          Female  512      NaN
# BMI                     1000.0    NaN             NaN  NaN  26.4432
# Headache                  1000      2             Yes  515      NaN
# Body_Ache                 1000      2             Yes  515      NaN
# Fatigue                   1000      2              No  508      NaN
# Chronic_Conditions        1000      2             Yes  516      NaN
# Allergies                 1000      2              No  522      NaN
# Smoking_History           1000      2             Yes  507      NaN
# Alcohol_Consumption       1000      2             Yes  523      NaN
# Humidity                1000.0    NaN             NaN  NaN  60.5944
# AQI                     1000.0    NaN             NaN  NaN  248.493
# Physical_Activity         1000      3          Active  365      NaN
# Diet_Type                 1000      3  Non-Vegetarian  348      NaN
# Heart_Rate              1000.0    NaN             NaN  NaN   80.144
# Blood_Pressure            1000      3             Low  345      NaN
# Previous_Medication        763      3       Ibuprofen  259      NaN
# Recommended_Medication    1000      2       Ibuprofen  801      NaN
#
#                                std   min     25%    50%     75%    max
# Temperature                1.13887  36.0    37.2   38.2    39.1   40.0
# Fever_Severity                 NaN   NaN     NaN    NaN     NaN    NaN
# Age                      28.873354   1.0    26.0   51.0    76.0  100.0
# Gender                         NaN   NaN     NaN    NaN     NaN    NaN
# BMI                        4.90115  18.0    22.4   26.5  30.525   35.0
# Headache                       NaN   NaN     NaN    NaN     NaN    NaN
# Body_Ache                      NaN   NaN     NaN    NaN     NaN    NaN
# Fatigue                        NaN   NaN     NaN    NaN     NaN    NaN
# Chronic_Conditions             NaN   NaN     NaN    NaN     NaN    NaN
# Allergies                      NaN   NaN     NaN    NaN     NaN    NaN
# Smoking_History                NaN   NaN     NaN    NaN     NaN    NaN
# Alcohol_Consumption            NaN   NaN     NaN    NaN     NaN    NaN
# Humidity                 17.058475  30.0    46.6  60.95  74.725   90.0
# AQI                     143.705244   0.0  127.75  247.5  375.25  499.0
# Physical_Activity              NaN   NaN     NaN    NaN     NaN    NaN
# Diet_Type                      NaN   NaN     NaN    NaN     NaN    NaN
# Heart_Rate                11.79196  60.0    70.0   80.0    90.0  100.0
# Blood_Pressure                 NaN   NaN     NaN    NaN     NaN    NaN
# Previous_Medication            NaN   NaN     NaN    NaN     NaN    NaN
# Recommended_Medication         NaN   NaN     NaN    NaN     NaN    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature             1000 non-null   float64
#  1   Fever_Severity          1000 non-null   object
#  2   Age                     1000 non-null   int64
#  3   Gender                  1000 non-null   object
#  4   BMI                     1000 non-null   float64
#  5   Headache                1000 non-null   object
#  6   Body_Ache               1000 non-null   object
#  7   Fatigue                 1000 non-null   object
#  8   Chronic_Conditions      1000 non-null   object
#  9   Allergies               1000 non-null   object
#  10  Smoking_History         1000 non-null   object
#  11  Alcohol_Consumption     1000 non-null   object
#  12  Humidity                1000 non-null   float64
#  13  AQI                     1000 non-null   int64
#  14  Physical_Activity       1000 non-null   object
#  15  Diet_Type               1000 non-null   object
#  16  Heart_Rate              1000 non-null   int64
#  17  Blood_Pressure          1000 non-null   object
#  18  Previous_Medication     763 non-null    object
#  19  Recommended_Medication  1000 non-null   object
# dtypes: float64(3), int64(3), object(14)
# memory usage: 156.4+ KB

# %%
Discrete_catagorical= ['Fever_Severity','Gender','Headache','Body_Ache','Fatigue','Chronic_Conditions','Allergies','Smoking_History','Alcohol_Consumption','Physical_Activity','Diet_Type','Blood_Pressure','Recommended_Medication']

# %%
Numerical = ['Temperature','Age','BMI','Humidity','AQI','Heart_Rate']

# %%
data.dtypes
# Out:
# Temperature               float64
# Fever_Severity             object
# Age                         int64
# Gender                     object
# BMI                       float64
# Headache                   object
# Body_Ache                  object
# Fatigue                    object
# Chronic_Conditions         object
# Allergies                  object
# Smoking_History            object
# Alcohol_Consumption        object
# Humidity                  float64
# AQI                         int64
# Physical_Activity          object
# Diet_Type                  object
# Heart_Rate                  int64
# Blood_Pressure             object
# Previous_Medication        object
# Recommended_Medication     object
# dtype: object

# %%
Discrete_catagorical = data.select_dtypes(include='object').columns
for col in Discrete_catagorical:
    print(f"{col}:\n{data[col].value_counts()}\n")
# Out:
# Fever_Severity:
# Fever_Severity
# High Fever    532
# Normal        269
# Mild Fever    199
# Name: count, dtype: int64
#
# Gender:
# Gender
# Female    512
# Male      488
# Name: count, dtype: int64
#
# Headache:
# Headache
# Yes    515
# No     485
# Name: count, dtype: int64
#
# Body_Ache:
# Body_Ache
# Yes    515
# No     485
# Name: count, dtype: int64
#
# Fatigue:
# Fatigue
# No     508
# Yes    492
# Name: count, dtype: int64
#
# Chronic_Conditions:
# Chronic_Conditions
# Yes    516
# No     484
# Name: count, dtype: int64
#
# Allergies:
# Allergies
# No     522
# Yes    478
# Name: count, dtype: int64
#
# Smoking_History:
# Smoking_History
# Yes    507
# No     493
# Name: count, dtype: int64
#
# Alcohol_Consumption:
# Alcohol_Consumption
# Yes    523
# No     477
# Name: count, dtype: int64
#
# Physical_Activity:
# Physical_Activity
# Active       365
# Sedentary    327
# Moderate     308
# Name: count, dtype: int64
#
# Diet_Type:
# Diet_Type
# Non-Vegetarian    348
# Vegan             332
# Vegetarian        320
# Name: count, dtype: int64
#
# Blood_Pressure:
# Blood_Pressure
# Low       345
# High      332
# Normal    323
# Name: count, dtype: int64
#
# Previous_Medication:
# Previous_Medication
# Ibuprofen      259
# Paracetamol    256
# Aspirin        248
# Name: count, dtype: int64
#
# Recommended_Medication:
# Recommended_Medication
# Ibuprofen      801
# Paracetamol    199
# Name: count, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis on discrete Variables

# %%
data[Discrete_catagorical].describe()
# Out:
#        Fever_Severity  Gender Headache Body_Ache Fatigue Chronic_Conditions  \
# count            1000    1000     1000      1000    1000               1000
# unique              3       2        2         2       2                  2
# top        High Fever  Female      Yes       Yes      No                Yes
# freq              532     512      515       515     508                516
#
#        Allergies Smoking_History Alcohol_Consumption Physical_Activity  \
# count       1000            1000                1000              1000
# unique         2               2                   2                 3
# top           No             Yes                 Yes            Active
# freq         522             507                 523               365
#
#              Diet_Type Blood_Pressure Previous_Medication  \
# count             1000           1000                 763
# unique               3              3                   3
# top     Non-Vegetarian            Low           Ibuprofen
# freq               348            345                 259
#
#        Recommended_Medication
# count                    1000
# unique                      2
# top                 Ibuprofen
# freq                      801

# %%
for col in Discrete_catagorical:
    sns.countplot(y=data[col], order=data[col].value_counts().index)
    plt.title(f"Count of {col}")
    plt.show()

# %% [markdown]
# # Exploratory Data Analysis on continous Variables

# %%
data[Numerical].describe()
# Out:
#        Temperature          Age         BMI     Humidity          AQI  \
# count   1000.00000  1000.000000  1000.00000  1000.000000  1000.000000
# mean      38.09890    51.152000    26.44320    60.594400   248.493000
# std        1.13887    28.873354     4.90115    17.058475   143.705244
# min       36.00000     1.000000    18.00000    30.000000     0.000000
# 25%       37.20000    26.000000    22.40000    46.600000   127.750000
# 50%       38.20000    51.000000    26.50000    60.950000   247.500000
# 75%       39.10000    76.000000    30.52500    74.725000   375.250000
# max       40.00000   100.000000    35.00000    90.000000   499.000000
#
#        Heart_Rate
# count  1000.00000
# mean     80.14400
# std      11.79196
# min      60.00000
# 25%      70.00000
# 50%      80.00000
# 75%      90.00000
# max     100.00000

# %%
Numerical= data.select_dtypes(include=['float64','int64']).columns

# %%
for cols in Numerical:
    sns.histplot(data[col], kde=True, bins=20)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
data[Numerical].skew()
# Out:
# Temperature   -0.143047
# Age           -0.019628
# BMI            0.006589
# Humidity      -0.061364
# AQI            0.022428
# Heart_Rate    -0.008225
# dtype: float64

# %% [markdown]
# # Checking for colinearity problem on continous variable

# %%
correlation_matrix= data[Numerical].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(data[Numerical])
plt.show()

# %%
for col in Discrete_catagorical:
    if col != 'Recommended_Medication':
        sns.countplot(x=data[col], hue=data['Recommended_Medication'])
        plt.title(f"{col} vs Recommended_Medication")
        plt.show()

# %% [markdown]
# # Checking for outliers

# %%
for col in Numerical:
    sns.boxplot(x=data['Recommended_Medication'], y=data[col])
    plt.title(f"{col} vs Recommended_Medication")
    plt.show()

# %% [markdown]
# # Step-3 Data Preparation

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
en=LabelEncoder()
for i in Discrete_catagorical:
      data[i]=en.fit_transform(data[i])

# %%
data
# Out:
#      Temperature  Fever_Severity  Age  Gender   BMI  Headache  Body_Ache  \
# 0           36.1               2   89       0  24.0         0          1
# 1           37.5               1   94       1  26.6         0          0
# 2           36.4               2   92       1  27.8         0          0
# 3           39.8               0   66       1  18.7         0          1
# 4           39.3               0   28       1  21.0         0          1
# ..           ...             ...  ...     ...   ...       ...        ...
# 995         39.9               0   59       1  22.1         1          1
# 996         36.9               2   74       0  18.1         1          1
# 997         36.1               2    8       0  29.6         1          1
# 998         38.8               0   87       0  25.2         0          0
# 999         38.2               0   65       0  26.0         0          1
#
#      Fatigue  Chronic_Conditions  Allergies  Smoking_History  \
# 0          0                   0          1                0
# 1          0                   1          0                1
# 2          0                   0          0                0
# 3          0                   0          0                0
# 4          0                   1          1                1
# ..       ...                 ...        ...              ...
# 995        1                   0          1                1
# 996        1                   1          1                0
# 997        0                   0          1                1
# 998        0                   0          0                0
# 999        0                   0          1                1
#
#      Alcohol_Consumption  Humidity  AQI  Physical_Activity  Diet_Type  \
# 0                      1      81.4  430                  1          1
# 1                      1      44.4   10                  0          2
# 2                      1      73.7  400                  2          1
# 3                      0      44.1  438                  0          0
# 4                      1      65.9  451                  0          2
# ..                   ...       ...  ...                ...        ...
# 995                    1      49.8   87                  2          2
# 996                    0      72.5  200                  2          2
# 997                    1      50.7  178                  1          2
# 998                    1      44.3  225                  2          0
# 999                    1      73.4   63                  0          0
#
#      Heart_Rate  Blood_Pressure  Previous_Medication  Recommended_Medication
# 0            72               2                    3                       0
# 1            62               0                    1                       1
# 2            85               0                    3                       0
# 3            96               0                    1                       0
# 4            85               1                    2                       0
# ..          ...             ...                  ...                     ...
# 995          67               2                    1                       0
# 996          83               0                    3                       0
# 997          97               0                    3                       0
# 998          97               0                    3                       0
# 999         100               2                    3                       0
#
# [1000 rows x 20 columns]

# %% [markdown]
# #x&y

# %%
X =data.drop('Recommended_Medication',axis=1)
y=data['Recommended_Medication']

# %% [markdown]
# # Train-Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test = train_test_split(X, test_size = 0.2, random_state = 42)
y_train,y_test= train_test_split(y,test_size=0.20,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
st = StandardScaler()
X_train=st.fit_transform(X_train)
X_test=st.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.44405713, -0.867651  ,  1.5928295 , ..., -1.62817462,
#         -1.22538299,  1.38907052],
#        [-1.05897348,  1.4773517 ,  1.35033038, ..., -0.78121468,
#          1.27539862,  1.38907052],
#        [-0.44007852,  0.30485035,  1.03854579, ...,  0.74331322,
#          1.27539862, -1.33905488],
#        ...,
#        [-0.88214635,  1.4773517 ,  1.45425857, ..., -0.01895073,
#          0.02500782,  0.47969538],
#        [-1.41262774,  1.4773517 ,  0.86533214, ..., -0.27303871,
#          0.02500782, -0.42967975],
#        [ 0.00198931, -0.867651  ,  0.9346176 , ..., -1.54347863,
#          1.27539862, -0.42967975]])

# %% [markdown]
# # Model and evaluation

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Logistic Regression

# %%
#Modelling
from sklearn.linear_model import LogisticRegression
log_model=LogisticRegression()
log_model.fit(X_train,y_train)

#Predict & Evaluate on train data
ypred_train=log_model.predict(X_train)
print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(log_model,X_train,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
ypred_test = log_model.predict(X_test)
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 0.79375
# CV Score : 0.7825
# Test Accuracy : 0.805

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,ypred_test))

from sklearn.metrics import classification_report
print(classification_report(y_test,ypred_test))
# Out:
# [[161   4]
#  [ 35   0]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.98      0.89       165
#            1       0.00      0.00      0.00        35
#
#     accuracy                           0.81       200
#    macro avg       0.41      0.49      0.45       200
# weighted avg       0.68      0.81      0.74       200

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
estimator= KNeighborsClassifier()
param_grid={'n_neighbors':list(range(1,50)),"p":[1,2]}
knn_grid=GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)
knn_grid.fit(X_train,y_train)
knn_grid.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=9, p=1)

# %%
knn_model=knn_grid.best_estimator_
knn_model.fit(X_train,y_train)

ypred_train=knn_model.predict(X_train)
print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(knn_model,X_train,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
ypred_test = knn_model.predict(X_test)
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 0.92875
# CV Score : 0.89875
# Test Accuracy : 0.925

# %% [markdown]
# # Support Vector Machine(SVM)

# %%
from sklearn.svm import SVC
estimator= SVC()
param_grid={'C':[0.01,0.1,1],'kernel':['linear','rbf','sigmoid','poly']}
svm_grid=GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)
svm_grid.fit(X_train,y_train)
svm_grid.best_estimator_
# Out:
# SVC(C=1)

# %%
svm_model=svm_grid.best_estimator_
svm_model.fit(X_train,y_train)

ypred_train=svm_model.predict(X_train)
print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(svm_model,X_train,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
ypred_test = svm_model.predict(X_test)
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 0.95625
# CV Score : 0.8324999999999999
# Test Accuracy : 0.885

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=True)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=True)

# %%
ypred_train=model.predict(X_train)
print("Train Accuracy :",accuracy_score(y_train,ypred_train))


#Predict and evaluate on test data
ypred_test = model.predict(X_test)
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 1.0
# Test Accuracy : 1.0

# %%
estimator= DecisionTreeClassifier(random_state=0)

param_grid={"criterion":["gini","entropy"],
           "max_depth":list(range(1,23))}

dt_grid = GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)

dt_grid.fit(X_train,y_train)
dt= dt_grid.best_estimator_
dt
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=0)

# %%
feats_dt = pd.DataFrame(data=dt.feature_importances_,
              index=X.columns,
              columns=['Importance'])
important_features_dt=feats_dt[feats_dt["Importance"]>0].index.tolist()

# %%
print(important_features_dt)
# Out:
# ['Temperature', 'Fever_Severity']

# %%
X_train = pd.DataFrame(X_train,columns = X.columns)
X_test = pd.DataFrame(X_test,columns = X.columns)

# %%
print(X_train.columns)
# Out:
# Index(['Temperature', 'Fever_Severity', 'Age', 'Gender', 'BMI', 'Headache',
#        'Body_Ache', 'Fatigue', 'Chronic_Conditions', 'Allergies',
#        'Smoking_History', 'Alcohol_Consumption', 'Humidity', 'AQI',
#        'Physical_Activity', 'Diet_Type', 'Heart_Rate', 'Blood_Pressure',
#        'Previous_Medication'],
#       dtype='object')

# %%
X_train_dt= X_train[important_features_dt]
X_test_dt= X_test[important_features_dt]

# modelling
dt= dt_grid.best_estimator_
dt.fit(X_train_dt,y_train)

#Evaluation
ypred_train=dt.predict(X_train_dt)
ypred_test=dt.predict(X_test_dt) 

print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(dt,X_train_dt,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 1.0
# CV Score : 1.0
# Test Accuracy : 1.0

# %% [markdown]
# # Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
estimator= RandomForestClassifier(random_state=True)
param_grid={'n_estimators':list(range(1,51))}
rf_grid=GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)
rf_grid.fit(X_train,y_train)
rf=rf_grid.best_estimator_
rf
# Out:
# RandomForestClassifier(n_estimators=7, random_state=True)

# %%
feats_ab = pd.DataFrame(data=rf.feature_importances_,
              index=X.columns,
              columns=['Importance'])
important_features_rf=feats_ab[feats_ab["Importance"]>0].index.tolist()
important_features_rf
# Out:
# ['Temperature',
#  'Fever_Severity',
#  'Age',
#  'Gender',
#  'BMI',
#  'Headache',
#  'Body_Ache',
#  'Fatigue',
#  'Chronic_Conditions',
#  'Allergies',
#  'Smoking_History',
#  'Alcohol_Consumption',
#  'Humidity',
#  'AQI',
#  'Physical_Activity',
#  'Diet_Type',
#  'Heart_Rate',
#  'Blood_Pressure',
#  'Previous_Medication']

# %%
rf.feature_importances_
# Out:
# array([4.40169638e-01, 3.51556619e-01, 2.62569219e-02, 6.17930559e-03,
#        3.39333557e-02, 6.31856133e-05, 2.66681890e-03, 4.22156975e-03,
#        1.93345592e-03, 6.67234158e-03, 3.39942312e-03, 1.17335836e-02,
#        3.01118015e-02, 2.27056474e-02, 7.17668025e-03, 5.38426084e-03,
#        2.18049073e-02, 4.81388395e-03, 1.92166005e-02])

# %%
X_train_rf= X_train[important_features_rf]
X_test_rf= X_test[important_features_rf]

#modelling
rf= rf_grid.best_estimator_
rf.fit(X_train_rf,y_train)

#Evaluation
ypred_train=rf.predict(X_train_rf)
ypred_test=rf.predict(X_test_rf) 

print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(rf,X_train_rf,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 1.0
# CV Score : 1.0
# Test Accuracy : 1.0

# %% [markdown]
# # Adaboost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
estimator= AdaBoostClassifier(random_state=True)
param_grid={'n_estimators':list(range(1,51))}
ab_grid=GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)
ab_grid.fit(X_train,y_train)
ab=ab_grid.best_estimator_
ab
# Out:
# AdaBoostClassifier(n_estimators=2, random_state=True)

# %%
feats_ab = pd.DataFrame(data=ab.feature_importances_,
              index=X.columns,
              columns=['Importance'])
important_features_ab=feats_ab[feats_ab["Importance"]>0].index.tolist()
important_features_ab
# Out:
# ['Fever_Severity']

# %%
X_train_ab= X_train[important_features_ab]
X_test_ab= X_test[important_features_ab]

#modelling
ab= ab_grid.best_estimator_
ab.fit(X_train_ab,y_train)

#Evaluation
ypred_train=ab.predict(X_train_ab)
ypred_test=ab.predict(X_test_ab) 

print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(ab,X_train_ab,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 1.0
# CV Score : 1.0
# Test Accuracy : 1.0

# %% [markdown]
# # Gradient Booster classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
estimator=GradientBoostingClassifier(random_state=True)
param_grid={"n_estimators":list(range(1,20))}
gb_grid=GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)
gb_grid.fit(X_train,y_train)
gb=gb_grid.best_estimator_
gb
# Out:
# GradientBoostingClassifier(n_estimators=5, random_state=True)

# %%
feats_gb = pd.DataFrame(data=gb.feature_importances_,
              index=X.columns,
              columns=['Importance'])
important_features_gb=feats_gb[feats_gb["Importance"]>0].index.tolist()
important_features_gb
# Out:
# ['Temperature', 'Fever_Severity', 'Age', 'BMI', 'AQI', 'Heart_Rate']

# %%
X_train_gb= X_train[important_features_gb]
X_test_gb= X_test[important_features_gb]

#modelling
gb= gb_grid.best_estimator_
gb.fit(X_train_gb,y_train)

#Evaluation
ypred_train=gb.predict(X_train_gb)
ypred_test=gb.predict(X_test_gb) 

print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(gb,X_train_gb,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 1.0
# CV Score : 1.0
# Test Accuracy : 1.0

# %% [markdown]
# # XGBoost Classifier

# %%
from xgboost import XGBClassifier
estimator=XGBClassifier()
param_grid={"n_estimators":[10,20,40,100],
           'max_depth':[3,4,5],
            'gamma':[0,0.15,0.3,0.5,1]}
xgb_grid=GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)
xgb_grid.fit(X_train,y_train)
xgb=gb_grid.best_estimator_
xgb
# Out:
# GradientBoostingClassifier(n_estimators=5, random_state=True)

# %%
len(X.columns)
# Out:
# 19

# %%
len(xgb.feature_importances_)
# Out:
# 6

# %%
feats_xgb = pd.DataFrame(data=xgb.feature_importances_,
              index=X.columns[:len(xgb.feature_importances_)],
              columns=['Importance'])
important_features_xgb=feats_xgb[feats_xgb["Importance"]>0].index.tolist()
important_features_xgb
# Out:
# ['Temperature', 'Fever_Severity', 'Age', 'Gender', 'BMI']

# %%
X_train_xgb= X_train[important_features_xgb]
X_test_xgb= X_test[important_features_xgb]

#modelling
xgb= xgb_grid.best_estimator_
xgb.fit(X_train_xgb,y_train)

#Evaluation
ypred_train=xgb.predict(X_train_xgb)
ypred_test=xgb.predict(X_test_xgb) 

print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(gb,X_train_xgb,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 1.0
# CV Score : 1.0
# Test Accuracy : 1.0

# %%
print(feats_dt.columns)

# %%
important_features = feats_dt[feats_dt["Importance"]>0].index.tolist()

# %%
print(important_features)

# %%
import pandas as pd
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)

# %%
print(X_train.columns)

# %%
print(X_test.shape)
