# %%
import numpy as np
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\sonia\Downloads\LoanData.csv")

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# # Step-2 Data Understanding

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data.drop(columns=['Loan_ID'], inplace=True)

# %%
data
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
data.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
data['Married'].unique()
data['Married'].value_counts()
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
data['Married'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
data['Dependents'].unique()
data['Dependents'].value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
data['Education'].unique()
data['Education'].value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
data['Self_Employed'].unique()
data['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64

# %%
data['Self_Employed'].unique()
data['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64

# %%
data["Income"]= data['ApplicantIncome']+data['CoapplicantIncome']
data.drop(columns=['ApplicantIncome','CoapplicantIncome'],inplace=True)

# %%
data["Income"].describe()
# Out:
# count      614.000000
# mean      7024.705081
# std       6458.663872
# min       1442.000000
# 25%       4166.000000
# 50%       5416.500000
# 75%       7521.750000
# max      81000.000000
# Name: Income, dtype: float64

# %%
data['Loan_Amount_Term'].unique()
data['Loan_Amount_Term'].value_counts()
# Out:
# Loan_Amount_Term
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
data['Credit_History'].unique()
data['Credit_History'].value_counts()
# Out:
# Credit_History
# 1.0    475
# 0.0     89
# Name: count, dtype: int64

# %%
data['Credit_History']= data['Credit_History'].replace({1:"good",0:"bad"})

# %%
data['Credit_History'].unique()
data['Credit_History'].value_counts()
# Out:
# Credit_History
# good    475
# bad      89
# Name: count, dtype: int64

# %%
data['Property_Area'].unique()
data['Property_Area'].value_counts()
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
data['Loan_Status'].unique()
data['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
Continous =['LoanAmount','Income']
Discrete_categorical=['Gender', 'Married', 'Education', 'Self_Employed', 'Credit_History', 'Property_Area','Loan_Status']
Discrete_count=['Dependents','Loan_Amount_Term']

# %%
data.dtypes
# Out:
# Gender               object
# Married              object
# Dependents           object
# Education            object
# Self_Employed        object
# LoanAmount          float64
# Loan_Amount_Term    float64
# Credit_History       object
# Property_Area        object
# Loan_Status          object
# Income              float64
# dtype: object

# %% [markdown]
# # Exploratory Data Analysis on continous Variables

# %%
data[Continous].describe()
# Out:
#        LoanAmount        Income
# count  592.000000    614.000000
# mean   146.412162   7024.705081
# std     85.587325   6458.663872
# min      9.000000   1442.000000
# 25%    100.000000   4166.000000
# 50%    128.000000   5416.500000
# 75%    168.000000   7521.750000
# max    700.000000  81000.000000

# %%
plt.rcParams['figure.figsize']=(9,6)
rwidth=2.5
plt.subplot(1,2, 1)
sns.histplot(data['Income'], kde=True)
plt.subplot(1,2, 2)
sns.histplot(data['LoanAmount'], kde=True)
plt.suptitle('Analysis on continous variable')
plt.show()

# %% [markdown]
# # Checking for skwness for contionus variables

# %%
data[Continous].skew()
# Out:
# LoanAmount    2.677552
# Income        5.633449
# dtype: float64

# %% [markdown]
# # Checking for colinearity problem on continous variable

# %%
sns.heatmap(data[Continous].corr(),annot=True)
plt.show()

# %% [markdown]
# high colinearity is observed between two input variables(high correlation betweeen two input variables) it should be less than 0.5

# %%
sns.pairplot(data[Continous])
plt.show()

# %% [markdown]
# # Exploratory Data Analysis on discrete Variables

# %%
data[Discrete_categorical].describe()
# Out:
#        Gender Married Education Self_Employed Credit_History Property_Area  \
# count     601     611       614           582            564           614
# unique      2       2         2             2              2             3
# top      Male     Yes  Graduate            No           good     Semiurban
# freq      489     398       480           500            475           233
#
#        Loan_Status
# count          614
# unique           2
# top              Y
# freq           422

# %%
plt.rcParams['figure.figsize']=(18,8)


plt.subplot(3, 2, 1)
sns.catplot(x=['Married'],kind="count",data=data, width=0.1)

plt.subplot(3, 2, 2)
sns.catplot(x=['Education'],kind="count",data=data, width=0.1)

plt.subplot(3, 2, 3)
sns.catplot(x=['Self_Employed'],kind="count",data=data, width=0.1)

plt.subplot(3, 2, 4)
sns.catplot(x=['Credit_History'],kind="count",data=data, width=0.1)

plt.subplot(3, 2, 5)
sns.catplot(x=['Property_Area'],kind="count",data=data, width=0.1)

plt.subplot(3, 2, 6)
sns.catplot(x=['Loan_Status'],kind="count",data=data, width=0.1)

plt.suptitle('Analysis on discrete variable')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23916\1528264325.py in ?()
#       1 plt.rcParams['figure.figsize']=(18,8)
#       2
#       3
#       4 plt.subplot(3, 2, 1)
# ----> 5 sns.catplot(x=['Married'],kind="count",data=data, width=0.1)
#       6
#       7 plt.subplot(3, 2, 2)
#       8 sns.catplot(x=['Education'],kind="count",data=data, width=0.1)
#
# ~\anaconda4\Lib\site-packages\seaborn\categorical.py in ?(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3183         "count": _CountPlotter,
#    3184     }[kind]
#    3185     p = _CategoricalPlotter()
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Gender            601 non-null    object
#  1   Married           611 non-null    object
#  2   Dependents        599 non-null    object
#  3   Education         614 non-null    object
#  4   Self_Employed     582 non-null    object
#  5   LoanAmount        592 non-null    float64
#  6   Loan_Amount_Term  600 non-null    float64
#  7   Credit_History    564 non-null    object
#  8   Property_Area     614 non-null    object
#  9   Loan_Status       614 non-null    object
#  10  Income            614 non-null    float64
# dtypes: float64(3), object(8)
# memory usage: 52.9+ KB

# %% [markdown]
# # Checking for missing values

# %%
data.isnull().sum()
# Out:
# Gender              13
# Married              3
# Dependents          15
# Education            0
# Self_Employed       32
# LoanAmount          22
# Loan_Amount_Term    14
# Credit_History      50
# Property_Area        0
# Loan_Status          0
# Income               0
# dtype: int64

# %% [markdown]
# # Checking for outliers

# %%
plt.subplot(1, 2, 1)
sns.boxplot(data['Income'])

plt.subplot(1, 2, 2)
sns.boxplot(data['LoanAmount'])
plt.suptitle('Outliers in data')
plt.show()

# %% [markdown]
# # Step-3 Data Preparation

# %% [markdown]
# # 1. Data Cleaning

# %% [markdown]
# # Wrong data treatment

# %%
data['Dependents']= data['Dependents'].replace({'3+':3})

# %% [markdown]
# # Missing values treatment

# %%
data['Dependents']= data['Dependents'].fillna(0)
data['Gender']= data['Gender'].fillna(data['Gender'].mode()[0])
data['Married']= data['Married'].fillna(data['Married'].mode()[0])
data['Self_Employed']= data['Self_Employed'].fillna(data['Self_Employed'].mode()[0])
data = data.dropna(subset=['LoanAmount','Loan_Amount_Term','Credit_History'])

# %% [markdown]
# # Datatype conversions

# %%
data['Dependents']= data['Dependents'].astype('int')
data['Loan_Amount_Term']= data['Loan_Amount_Term'].astype('int')

# %% [markdown]
# # Outliers

# %% [markdown]
# some people have high income so retrain outliers

# %% [markdown]
# # Encoding

# %% [raw]
# data['Gender']= data['Gender'].replace({'Male':1,'Female':0})
# data['Married']= data['Married'].replace({'Yes':1,'No':0})
# data['Education']= data['Education'].replace({'Graduate':1,'Not Graduate':0})
# data['Self_Employed']= data['Self_Employed'].replace({'Yes':1,'No':0})
# data['Property_Area']= data['Property_Area'].replace({'Rural':0,'Semiurban':1,'Urban':2})
# data['Loan_Status']= data['Loan_Status'].replace({'Yes':1,'No':0})
# data['Credit_History']= data['Credit_History'].replace({'good':1,'bad':0})

# %%
data['Loan_Status']
# Out:
# 1      N
# 2      Y
# 3      Y
# 4      Y
# 5      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 529, dtype: object

# %% [markdown]
# data['Gender']= data['Gender'].replace({'Male':1,'Female':0}).astype('int')
# data['Married']= data['Married'].replace({'Yes':1,'No':0}).astype('int')
# data['Education']= data['Education'].replace({'Graduate':1,'Not Graduate':0}).astype('int')
# data['Self_Employed']= data['Self_Employed'].replace({'Yes':1,'No':0}).astype('int')
# data['Property_Area']= data['Property_Area'].replace({'Rural':0,'Semiurban':1,'Urban':2}).astype('int')
# data['Loan_Status']= data['Loan_Status'].replace({'Y':1,'N':0}).astype('int')
# data['Credit_History']= data['Credit_History'].replace({'good':1,'bad':0}).astype('int')

# %%
data['Gender']= data['Gender'].replace({'Male':1,'Female':0}).astype('int') 
data['Married']= data['Married'].replace({'Yes':1,'No':0}).astype('int') 
data['Education']= data['Education'].replace({'Graduate':1,'Not Graduate':0}).astype('int') 
data['Self_Employed']= data['Self_Employed'].replace({'Yes':1,'No':0}).astype('int') 
data['Property_Area']= data['Property_Area'].replace({'Rural':0,'Semiurban':1,'Urban':2}).astype('int') 
data['Loan_Status']= data['Loan_Status'].replace({'Y':1,'N':0}).astype('int') 
data['Credit_History']= data['Credit_History'].replace({'good':1,'bad':0}).astype('int')

# %%
data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 1         1        1           1          1              0       128.0
# 2         1        1           0          1              1        66.0
# 3         1        1           0          0              0       120.0
# 4         1        0           0          1              0       141.0
# 5         1        1           2          1              1       267.0
# ..      ...      ...         ...        ...            ...         ...
# 609       0        0           0          1              0        71.0
# 610       1        1           3          1              0        40.0
# 611       1        1           1          1              0       253.0
# 612       1        1           2          1              0       187.0
# 613       0        0           0          1              1       133.0
#
#      Loan_Amount_Term  Credit_History  Property_Area  Loan_Status  Income
# ...

# %% [markdown]
# # Transformation

# %%
import numpy as np
from scipy import stats
from scipy.stats import boxcox
data['Income'],a = boxcox(data['Income'])
data['LoanAmount'],c = boxcox(data['LoanAmount'])

# %%
data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 1         1        1           1          1              0    4.926065
# 2         1        1           0          1              1    3.673829
# 3         1        1           0          0              0    4.799238
# 4         1        0           0          1              0    5.118143
# 5         1        1           2          1              1    6.447421
# ..      ...      ...         ...        ...            ...         ...
# 609       0        0           0          1              0    3.806594
# 610       1        1           3          1              0    2.797606
# 611       1        1           1          1              0    6.331082
# 612       1        1           2          1              0    5.692657
# 613       0        0           0          1              1    5.001869
#
#      Loan_Amount_Term  Credit_History  Property_Area  Loan_Status    Income
# ...

# %%
data['Loan_Amount_Term'] = data['Loan_Amount_Term']/12

# %%
data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 1         1        1           1          1              0       128.0
# 2         1        1           0          1              1        66.0
# 3         1        1           0          0              0       120.0
# 4         1        0           0          1              0       141.0
# 5         1        1           2          1              1       267.0
# ..      ...      ...         ...        ...            ...         ...
# 609       0        0           0          1              0        71.0
# 610       1        1           3          1              0        40.0
# 611       1        1           1          1              0       253.0
# 612       1        1           2          1              0       187.0
# 613       0        0           0          1              1       133.0
#
#      Loan_Amount_Term  Credit_History  Property_Area  Loan_Status  Income
# ...

# %%
col=['LoanAmount','Income','Loan_Amount_Term']
from sklearn.preprocessing import StandardScaler
st = StandardScaler()
X[col]= st.fit_transform(X[col])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       2 from sklearn.preprocessing import StandardScaler
#       3 st = StandardScaler()
# ----> 4 X[col]= st.fit_transform(X[col])
#
# NameError: name 'X' is not defined

# %% [markdown]
# # x&y

# %%
X =data.drop('Loan_Status',axis=1)
y=data['Loan_Status']

# %% [markdown]
# #Feature Scaling

# %%
col=['LoanAmount','Income','Loan_Amount_Term']
from sklearn.preprocessing import StandardScaler
st = StandardScaler()
X[col]= st.fit_transform(X[col])

# %%
data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 1         1        1           1          1              0    4.926065
# 2         1        1           0          1              1    3.673829
# 3         1        1           0          0              0    4.799238
# 4         1        0           0          1              0    5.118143
# 5         1        1           2          1              1    6.447421
# ..      ...      ...         ...        ...            ...         ...
# 609       0        0           0          1              0    3.806594
# 610       1        1           3          1              0    2.797606
# 611       1        1           1          1              0    6.331082
# 612       1        1           2          1              0    5.692657
# 613       0        0           0          1              1    5.001869
#
#      Loan_Amount_Term  Credit_History  Property_Area  Loan_Status    Income
# ...

# %% [markdown]
# # Train-Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test = train_test_split(X, test_size = 0.2, random_state = 42)
y_train,y_test= train_test_split(y,test_size=0.20,random_state=42)

# %%
y_test.info
# Out:
# <bound method Series.info of 168    0
# 464    0
# 7      0
# 390    1
# 376    1
#       ..
# 398    1
# 534    1
# 158    1
# 396    0
# 596    0
# Name: Loan_Status, Length: 106, dtype: int32>

# %% [markdown]
# # Model and evaluation

# %%
# !pip install xgboost

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Logistic Regression

# %%
#Modelling
from sklearn.linear_model import LogisticRegression
log_model=LogisticRegression()
log_model.fit(X_train,y_train)

#Predict & Evaluate on train data
ypred_train=log_model.predict(X_train)
print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(log_model,X_train,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
ypred_test = log_model.predict(X_test)
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 0.8108747044917257
# CV Score : 0.8085434173669468
# Test Accuracy : 0.8301886792452831

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,ypred_test))

from sklearn.metrics import classification_report
print(classification_report(y_test,ypred_test))
# Out:
# [[16 17]
#  [ 1 72]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.48      0.64        33
#            1       0.81      0.99      0.89        73
#
#     accuracy                           0.83       106
#    macro avg       0.88      0.74      0.76       106
# weighted avg       0.85      0.83      0.81       106

# %% [markdown]
# # KNN

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.neighbors import KNeighborsClassifier
estimator= KNeighborsClassifier()
param_grid={'n_neighbors':list(range(1,50)),"p":[1,2]}
knn_grid=GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)
knn_grid.fit(X_train,y_train)
knn_grid.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=10, p=1)

# %% [markdown]
# # Modelling and evaluation

# %%
knn_model=knn_grid.best_estimator_
knn_model.fit(X_train,y_train)

ypred_train=knn_model.predict(X_train)
print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(knn_model,X_train,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
ypred_test = knn_model.predict(X_test)
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 0.7943262411347518
# CV Score : 0.763641456582633
# Test Accuracy : 0.7641509433962265

# %% [markdown]
# # Support Vector Machine(SVM)

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.svm import SVC
estimator= SVC()
param_grid={'C':[0.01,0.1,1],'kernel':['linear','rbf','sigmoid','poly']}
svm_grid=GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)
svm_grid.fit(X_train,y_train)
svm_grid.best_estimator_
# Out:
# SVC(C=0.1, kernel='linear')

# %% [markdown]
# # Modelling and evaluation

# %%
svm_model=svm_grid.best_estimator_
svm_model.fit(X_train,y_train)

ypred_train=svm_model.predict(X_train)
print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(svm_model,X_train,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
ypred_test = svm_model.predict(X_test)
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 0.8108747044917257
# CV Score : 0.8109243697478992
# Test Accuracy : 0.8301886792452831

# %% [markdown]
# # Decision Tree Classifier

# %% [markdown]
# #First Create deafault DT model (fully grown tree without any pruning)so that,we can understandthe max_depth

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=True)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=True)

# %%
y_train
# Out:
# 164    1
# 610    1
# 485    1
# 432    1
# 84     1
#       ..
# 87     1
# 132    1
# 315    1
# 509    1
# 124    1
# Name: Loan_Status, Length: 423, dtype: int32

# %% [markdown]
# # hyperparmeter tuning

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20,20),dpi=200)
plot_tree(model,filled=True,
          feature_names=X_train.columns.tolist(),
          class_names =["0","1"])
plt.show()

# %%
estimator= DecisionTreeClassifier(random_state=0)

param_grid={"criterion":["gini","entropy"],
           "max_depth":list(range(1,23))}

dt_grid = GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)

dt_grid.fit(X_train,y_train)
dt= dt_grid.best_estimator_
dt
# Out:
# DecisionTreeClassifier(max_depth=1, random_state=0)

# %%
feats_dt = pd.DataFrame(data=dt.feature_importances_,
              index=X.columns,
              columns=['Importance'])
important_features_dt=feats_dt[feats_dt["Importance"]>0].index.tolist()
important_features_dt
# Out:
# ['Credit_History']

# %%
X_train_dt= X_train[important_features_dt]
X_test_dt= X_test[important_features_dt]

#modelling
dt= dt_grid.best_estimator_
dt.fit(X_train_dt,y_train)

#Evaluation
ypred_train=dt.predict(X_train_dt)
ypred_test=dt.predict(X_test_dt) 

print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(dt,X_train_dt,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 0.8108747044917257
# CV Score : 0.8109243697478992
# Test Accuracy : 0.8301886792452831

# %% [markdown]
# # Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
estimator= RandomForestClassifier(random_state=True)
param_grid={'n_estimators':list(range(1,51))}
rf_grid=GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)
rf_grid.fit(X_train,y_train)
rf=rf_grid.best_estimator_
rf
# Out:
# RandomForestClassifier(n_estimators=39, random_state=True)

# %% [markdown]
# #IMportant features

# %%
feats_ab = pd.DataFrame(data=rf.feature_importances_,
              index=X.columns,
              columns=['Importance'])
important_features_rf=feats_ab[feats_ab["Importance"]>0].index.tolist()
important_features_rf
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Income']

# %%
rf.feature_importances_
# Out:
# array([0.02184414, 0.02854937, 0.05447303, 0.02289046, 0.0234891 ,
#        0.22941912, 0.04671725, 0.25852558, 0.05955013, 0.25454183])

# %%
rf_grid.best_estimator_.feature_importances_
# Out:
# array([0.02184414, 0.02854937, 0.05447303, 0.02289046, 0.0234891 ,
#        0.22941912, 0.04671725, 0.25852558, 0.05955013, 0.25454183])

# %%
feats_ab = pd.DataFrame(data=rf.feature_importances_,
              index=X.columns,
              columns=['Importance'])
important_features_rf=feats_ab[feats_ab["Importance"]>0].index.tolist()
important_features_rf
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Income']

# %%
X_train_rf= X_train[important_features_rf]
X_test_rf= X_test[important_features_rf]

#modelling
rf= rf_grid.best_estimator_
rf.fit(X_train_rf,y_train)

#Evaluation
ypred_train=rf.predict(X_train_rf)
ypred_test=rf.predict(X_test_rf) 

print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(rf,X_train_rf,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 1.0
# CV Score : 0.7920168067226891
# Test Accuracy : 0.8113207547169812

# %% [markdown]
# # Adaboost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
estimator= AdaBoostClassifier(random_state=True)
param_grid={'n_estimators':list(range(1,51))}
ab_grid=GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)
ab_grid.fit(X_train,y_train)
ab=ab_grid.best_estimator_
ab
# Out:
# AdaBoostClassifier(n_estimators=1, random_state=True)

# %%
from sklearn.ensemble import AdaBoostClassifier
estimator= AdaBoostClassifier(random_state=True)

# %%
feats_ab = pd.DataFrame(data=ab.feature_importances_,
              index=X.columns,
              columns=['Importance'])
important_features_ab=feats_ab[feats_ab["Importance"]>0].index.tolist()
important_features_ab
# Out:
# ['Credit_History']

# %%
X_train_ab= X_train[important_features_ab]
X_test_ab= X_test[important_features_ab]

#modelling
ab= ab_grid.best_estimator_
ab.fit(X_train_ab,y_train)

#Evaluation
ypred_train=ab.predict(X_train_ab)
ypred_test=ab.predict(X_test_ab) 

print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(ab,X_train_ab,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 0.8108747044917257
# CV Score : 0.8109243697478992
# Test Accuracy : 0.8301886792452831

# %% [markdown]
# # Gradient Booster classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
estimator=GradientBoostingClassifier(random_state=True)
param_grid={"n_estimators":list(range(1,20))}
gb_grid=GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)
gb_grid.fit(X_train,y_train)
gb=gb_grid.best_estimator_
gb
# Out:
# GradientBoostingClassifier(n_estimators=5, random_state=True)

# %%
feats_gb = pd.DataFrame(data=gb.feature_importances_,
              index=X.columns,
              columns=['Importance'])
important_features_gb=feats_gb[feats_gb["Importance"]>0].index.tolist()
important_features_gb
# Out:
# ['Married',
#  'Education',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Income']

# %%
X_train_gb= X_train[important_features_gb]
X_test_gb= X_test[important_features_gb]

#modelling
gb= gb_grid.best_estimator_
gb.fit(X_train_gb,y_train)

#Evaluation
ypred_train=gb.predict(X_train_gb)
ypred_test=gb.predict(X_test_gb) 

print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(gb,X_train_gb,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 0.8156028368794326
# CV Score : 0.8062184873949579
# Test Accuracy : 0.8301886792452831

# %% [markdown]
# # XGBoost Classifier

# %%
from xgboost import XGBClassifier

# %%
estimator=XGBClassifier()
param_grid={"n_estimators":[10,20,40,100],
           'max_depth':[3,4,5],
            'gamma':[0,0.15,0.3,0.5,1]}
xgb_grid=GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)
xgb_grid.fit(X_train,y_train)
xgb=gb_grid.best_estimator_
xgb
# Out:
# GradientBoostingClassifier(n_estimators=5, random_state=True)

# %%
feats_xgb = pd.DataFrame(data=xgb.feature_importances_,
              index=X.columns,
              columns=['Importance'])
important_features_xgb=feats_xgb[feats_xgb["Importance"]>0].index.tolist()
important_features_xgb
# Out:
# ['Married',
#  'Education',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Income']

# %%
X_train_xgb= X_train[important_features_xgb]
X_test_xgb= X_test[important_features_xgb]

#modelling
xgb= xgb_grid.best_estimator_
xgb.fit(X_train_xgb,y_train)

#Evaluation
ypred_train=xgb.predict(X_train_xgb)
ypred_test=xgb.predict(X_test_xgb) 

print("Train Accuracy :",accuracy_score(y_train,ypred_train))

#cross validation on train data
print("CV Score :",cross_val_score(gb,X_train_xgb,y_train,cv=5,scoring="accuracy").mean())

#Predict and evaluate on test data
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 0.8416075650118203
# CV Score : 0.8062184873949579
# Test Accuracy : 0.8113207547169812

# %% [markdown]
# # save the best model

# %%
from joblib import dump

dump(dt,'loan.joblib')
# Out:
# ['loan.joblib']

# %%
data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 1         1        1           1          1              0    4.926065
# 2         1        1           0          1              1    3.673829
# 3         1        1           0          0              0    4.799238
# 4         1        0           0          1              0    5.118143
# 5         1        1           2          1              1    6.447421
# ..      ...      ...         ...        ...            ...         ...
# 609       0        0           0          1              0    3.806594
# 610       1        1           3          1              0    2.797606
# 611       1        1           1          1              0    6.331082
# 612       1        1           2          1              0    5.692657
# 613       0        0           0          1              1    5.001869
#
#      Loan_Amount_Term  Credit_History  Property_Area  Loan_Status    Income
# ...

# %%
input_data={"Loan_ID":"LP001002",	
"Gender":"Male",	
"Married":"No",	
"Dependents":"0",	
"Education":"Graduate",	
"Self_Employed":"yes",	
"ApplicantIncome":1000,	
"CoapplicantIncome":0,	
"LoanAmount":100,	
"Loan_Amount_Term":240,
"Credit_History":"good",
"property_Area":"Urban"}

# %%
data= pd.DataFrame(input_data,index=[0])
data
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate           yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             1000                  0         100               240
#
#   Credit_History property_Area
# 0           good         Urban

# %% [markdown]
# # Apply data processing on unkown data

# %%
data.drop(columns=["Loan_ID"],inplace=True)
data["Income"]= data['ApplicantIncome']+data['CoapplicantIncome']
data.drop(columns=['ApplicantIncome','CoapplicantIncome'],inplace=True)
data['Dependents']= data['Dependents'].replace({'3+':3})
data['Dependents']= data['Dependents'].fillna(0)
data['Gender']= data['Gender'].fillna(data['Gender'].mode()[0])
data['Married']= data['Married'].fillna(data['Married'].mode()[0])
data['Self_Employed']= data['Self_Employed'].fillna(data['Self_Employed'].mode()[0])
data = data.dropna(subset=['LoanAmount','Loan_Amount_Term','Credit_History'])
data['Dependents']= data['Dependents']
data['Loan_Amount_Term']= data['Loan_Amount_Term'].astype('int')
data['Gender']= data['Gender'].replace({'Male':1,'Female':0})
data['Married']= data['Married'].replace({'Yes':1,'No':0})
data['Education']= data['Education'].replace({'Graduate':1,'Not Graduate':0})
data['Self_Employed']= data['Self_Employed'].replace({'Yes':1,'No':0})
data['property_Area']= data['property_Area'].replace({'Rural':0,'Semiurban':1,'Urban':2})
data['Credit_History']= data['Credit_History'].replace({'good':1,'bad':0})
data['Loan_Amount_Term'] = data['Loan_Amount_Term']/12

X_new= data

# %%
X_new = X_new[important_features_dt]
dt.predict(X_new)
# Out:
# array([1])
